# %%
import pandas as pd
df=pd.read_csv('tweets.csv',encoding='ISO-8859-1')

# %%
df.head(7)
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
# 5           6  6  @DerekScissors1: Indias #demonetization: #Bla...
# 6           7  7  RT @gauravcsawant: Rs 40 lakh looted from a ba...
#
#    favorited  favoriteCount       replyToSN              created  truncated  \
# 0      False              0             NaN  2016-11-23 18:40:30      False
# 1      False              0             NaN  2016-11-23 18:40:29      False
# 2      False              0             NaN  2016-11-23 18:40:03      False
# 3      False              0             NaN  2016-11-23 18:39:59      False
# 4      False              0             NaN  2016-11-23 18:39:39      False
# 5      False              0  DerekScissors1  2016-11-23 18:39:11      False
# 6      False              0             NaN  2016-11-23 18:38:53      False
#
#    replyToSID            id    replyToUID  \
# 0         NaN  8.014957e+17           NaN
# 1         NaN  8.014957e+17           NaN
# 2         NaN  8.014955e+17           NaN
# 3         NaN  8.014955e+17           NaN
# 4         NaN  8.014954e+17           NaN
# 5         NaN  8.014953e+17  2.586266e+09
# 6         NaN  8.014952e+17           NaN
#
#                                         statusSource       screenName  \
# 0  <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1  <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2  <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3  <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4  <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
# 5  <a href="http://twitter.com" rel="nofollow">Tw...      ambazaarmag
# 6  <a href="http://twitter.com/download/android" ...          bhodia1
#
#    retweetCount  isRetweet  retweeted
# 0           331       True      False
# 1            66       True      False
# 2            12       True      False
# 3           338       True      False
# 4           120       True      False
# 5             0      False      False
# 6           637       True      False

# %%
import re

def clean_text(text):
    text=re.sub(r'RT','',text)
    text=re.sub(r'&amp;','',text)
    text=re.sub(r'[?!.:;,#@-]','',text)
    text=text.lower()
    return text

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
#      ------------------------------------- 299.8/299.8 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhanu\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhanu\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: six>=1.5 in c:\users\dhanu\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from wordcloud import STOPWORDS

print(STOPWORDS)
# Out:
# {'an', 'both', 'are', 'she', "they'd", "he'd", 'just', "don't", 'under', 'while', 'against', 'so', "she'll", 'further', 'there', 'that', 'and', 'ourselves', 'of', 'r', "you're", "when's", 'your', 'am', 'doing', 'why', 'with', 'below', 'more', 'what', 'theirs', "they're", 'myself', 'being', "isn't", "hasn't", 'at', 'otherwise', "what's", 'than', 'then', "where's", "i'd", "couldn't", 'which', 'into', 'their', 'has', 'because', 'some', 'before', 'these', 'we', 'nor', "shouldn't", 'above', 'most', 'from', 'was', "who's", 'cannot', 'own', 'in', "why's", 'too', 'yours', 'by', 'himself', "you'd", "doesn't", "they've", "he'll", 'can', "can't", 'same', 'ever', 'each', "wouldn't", 'www', 'his', "aren't", 'this', "shan't", 'were', 'herself', "i'm", "we'll", "how's", "won't", 'a', 'have', 'about', 'me', 'yourself', 'who', "we'd", 'or', "i've", 'here', 'those', 'as', "that's", 'they', 'hers', 'the', 'since', 'between', 'i', "we've", 'did', 'all', 'is', 'her', 'com', 'my', "didn't", 'like', 'again', 'itself', 'could', 'on', 'hence', 'very', 'but', 'else', 'how', 'to', 'had', "she'd", 'our', 'whom', 'you', "it's", 'k', 'however', 'ought', "they'll", 'out', 'therefore', 'shall', "you've", 'been', 'do', 'once', "she's", "he's", "here's", 'where', 'other', 'after', 'does', 'it', 'if', 'also', 'down', 'until', 'yourselves', "wasn't", "hadn't", 'ours', 'such', 'be', 'http', 'no', 'for', 'during', 'its', "weren't", 'having', 'get', "let's", "there's", 'he', 'over', "mustn't", 'only', 'few', 'him', "haven't", "i'll", 'not', 'would', 'through', 'them', "we're", 'off', 'any', 'should', 'when', "you'll", 'up', 'themselves'}
